# %% [markdown]
# Nicolas Kardous

# %% [markdown]
# INDENG 265

# %% [markdown]
# Homework 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv

# %% [markdown]
# ## Problem 3

# %%
plt.subplots(figsize=(20,20))
plt.scatter(range(len(theta_d)),theta_d)
plt.title("Coefficients for different features from Gradient Descent")
plt.xlabel("Feature numbers")
plt.ylabel("Coefficients")
plt.show()

# %% [markdown]
# ## Part e)

# %%
# Implement Stochastic Gradient Descent

alpha = 0.0001
T = 100000
theta_e = np.zeros(231)

for i in range(T):
    batch=np.random.randint(5000)
    Gradient =(-1)*(Y[batch]-phi[batch].dot(theta_e))*(phi[batch])
    theta_e -= alpha*Gradient

print("Coefficients of fitted polynomial is: \n",theta_e)
# Out:
# Coefficients of fitted polynomial is:
#  [-0.00153588 -0.9990061   0.99543614 -1.00738609  0.9966593  -0.9956533
#   1.0099567  -1.00037808  1.00022347 -0.99998968  0.99154142 -0.99739297
#   0.99521066 -1.00059081  1.00549683 -1.00026527  1.00043316 -1.01021387
#   0.99941894 -0.99977659  1.00173949 -1.04394876  0.99971696 -0.99591249
#   0.99893392 -1.00684717  1.00440926 -0.99189077  1.00002913 -1.000342
#   0.99872985 -0.99637949  0.99557472 -1.00097774  1.0029034  -0.99998212
#   1.00058892 -0.99606123  1.00149942 -1.00236135  1.00067687 -1.04942124
#   1.00066793 -0.99883586  1.00151478 -1.00475512  0.99470302 -0.99763396
#   0.99592696 -0.99928893  0.99814586 -0.996786    1.00245844 -0.99276478
#   1.00050922 -1.00185852  0.99767838 -0.99751055  1.00203911 -0.99989277
#   0.94749403 -0.99612844  1.00463028 -0.98949491  1.00431552 -0.99509811
#   1.00441563 -1.00473986  1.00330442 -1.00289874  1.00895593 -1.00009539
# ...

# %%
plt.subplots(figsize=(20,20))
plt.scatter(range(len(theta_e)),theta_e)
plt.title("Coefficients for different features from Stochastic Gradient Descent")
plt.xlabel("Feature numbers")
plt.ylabel("Coefficients")
plt.show()

# %% [markdown]
# Calculate different between optimal theta, theta_d and theta_e

# %%
diff1 = theta-theta_d
diff2 = theta-theta_e
print(sum(diff1))
print(sum(diff2))
# Out:
# 0.07299014730461056
# 0.029940712216672966
